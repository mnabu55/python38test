# %%
# !wget https://storage.googleapis.com/tensorflow-1-public/course2/week3/horse-or-human.zip
# Out:
# --2022-07-29 11:03:33--  https://storage.googleapis.com/tensorflow-1-public/course2/week3/horse-or-human.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.194.128, 173.194.195.128, 173.194.192.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.194.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149574867 (143M) [application/zip]
# Saving to: ‘horse-or-human.zip’
#
# horse-or-human.zip  100%[===================>] 142.65M   165MB/s    in 0.9s
#
# 2022-07-29 11:03:34 (165 MB/s) - ‘horse-or-human.zip’ saved [149574867/149574867]

# %%
import zipfile

local_zip = './horse-or-human.zip'
zip_ref = zipfile.ZipFile(local_zip)
zip_ref.extractall('./horse-or-human')
zip_ref.close()

# %%
import os

train_horse_dir = os.path.join('./horse-or-human/horses')
train_human_dir = os.path.join('./horse-or-human/humans')

train_horse_dir
# Out:
# './horse-or-human/horses'

# %%
train_horse_names = os.listdir(train_horse_dir)
print(len(train_horse_names))
print(train_horse_names[:10])

train_human_names = os.listdir(train_human_dir)
print(train_human_names[:10])
# Out:
# 500
# ['horse08-2.png', 'horse21-9.png', 'horse48-5.png', 'horse04-8.png', 'horse30-4.png', 'horse38-5.png', 'horse01-6.png', 'horse08-4.png', 'horse50-1.png', 'horse41-0.png']
# ['human08-17.png', 'human03-18.png', 'human11-15.png', 'human02-20.png', 'human07-20.png', 'human03-03.png', 'human01-07.png', 'human12-15.png', 'human08-18.png', 'human03-28.png']

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=(300, 300, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 298, 298, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 149, 149, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 147, 147, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 73, 73, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 35, 35, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 33, 33, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 512)               8389120
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 8,450,145
# Trainable params: 8,450,145
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(loss='binary_crossentropy',
              optimizer=RMSprop(learning_rate=0.001),
              metrics=['accuracy']
              )

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255)
train_generator = train_datagen.flow_from_directory(
    './horse-or-human/',
    target_size=(300, 300),
    batch_size=128,
    class_mode='binary'
)
# Out:
# Found 1027 images belonging to 2 classes.

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=8,
    epochs=15,
    verbose=1
)
# Out:
# Epoch 1/15
# 8/8 [==============================] - 20s 685ms/step - loss: 1.7470 - accuracy: 0.5684
# Epoch 2/15
# 8/8 [==============================] - 6s 765ms/step - loss: 1.3203 - accuracy: 0.7208
# Epoch 3/15
# 8/8 [==============================] - 6s 757ms/step - loss: 0.3900 - accuracy: 0.8532
# Epoch 4/15
# 8/8 [==============================] - 7s 876ms/step - loss: 0.4501 - accuracy: 0.8623
# Epoch 5/15
# 8/8 [==============================] - 7s 848ms/step - loss: 0.1277 - accuracy: 0.9492
# Epoch 6/15
# 8/8 [==============================] - 6s 756ms/step - loss: 0.3650 - accuracy: 0.8899
# Epoch 7/15
# 8/8 [==============================] - 6s 741ms/step - loss: 0.1015 - accuracy: 0.9644
# Epoch 8/15
# 8/8 [==============================] - 6s 754ms/step - loss: 0.0949 - accuracy: 0.9622
# Epoch 9/15
# 8/8 [==============================] - 6s 885ms/step - loss: 0.0124 - accuracy: 0.9967
# Epoch 10/15
# 8/8 [==============================] - 6s 732ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 11/15
# 8/8 [==============================] - 6s 762ms/step - loss: 1.2789 - accuracy: 0.8565
# Epoch 12/15
# 8/8 [==============================] - 6s 748ms/step - loss: 0.2249 - accuracy: 0.9433
# Epoch 13/15
# 8/8 [==============================] - 6s 755ms/step - loss: 0.0290 - accuracy: 0.9933
# Epoch 14/15
# 8/8 [==============================] - 6s 758ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 15/15
# 8/8 [==============================] - 6s 765ms/step - loss: 0.0068 - accuracy: 0.9989
